# %%
import numpy as np
import pandas as pd
from os import listdir
from os.path import isfile, isdir, join

# %%
data_path = '../Data/cleansed_data/'
data = listdir(data_path)
i = 0
for f in data:
    fullpath = join(data_path, f)
    if isfile(fullpath):
        if f.find('csv') != -1:
            df_name = 'df_' + f
            exec("%s = pd.read_csv('%s')" % (df_name[:-4], data_path + f))

# %%
#print(df_automobile_sale_01_08,
#      df_automobile_sale_09_19, 
#      df_coal_consump_01_08, 
#      df_coal_consump_09_19, 
#      df_CPI_01_08, 
#      df_CPI_09_19,
#      df_natural_gas_consump_01_08,
#      df_natural_gas_consump_09_19,
#      df_treescover_loss_01_08,
#      df_treescover_loss_09_19,
#      df_US_real_GDP_01_08,
#      df_US_real_GDP_09_19)
# Out:
#            DATE    TOTALSA
# 0    2001-01-07  17.629145
# 1    2001-01-14  17.850691
# 2    2001-01-21  16.499039
# 3    2001-01-28  14.163210
# 4    2001-02-04  16.917572
# ..          ...        ...
# 412  2008-11-30  10.745410
# 413  2008-12-07  12.533865
# 414  2008-12-14  10.298568
# 415  2008-12-21   9.594489
# 416  2008-12-28  10.409944
#
# [417 rows x 2 columns]            DATE    TOTALSA
# 0    2009-01-04  10.535732
# 1    2009-01-11   8.347124
# 2    2009-01-18   8.574011
# 3    2009-01-25   8.961935
# 4    2009-02-01   9.348876
# ..          ...        ...
# 569  2019-12-01  17.941804
# 570  2019-12-08  14.872529
# 571  2019-12-15  18.616565
# 572  2019-12-22  16.962709
# 573  2019-12-29  17.838750
#
# [574 rows x 2 columns]      Unnamed: 0          Value
# 0    2001-01-07   96641.568591
# 1    2001-01-14   89172.960369
# 2    2001-01-21  100533.687656
# 3    2001-01-28  101753.621895
# 4    2001-02-04   61448.503210
# ..          ...            ...
# ...
