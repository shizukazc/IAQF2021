# %%
import numpy as np
import pandas as pd
import datetime

# %%
path = '../raw_data/USpopulation_1959Jan-2020Nov_monthly.csv'

df = pd.read_csv(path, index_col='DATE')
df.index = pd.to_datetime(df.index)
df
# Out:
#               POPTHM
# DATE
# 1959-01-01  175818.0
# 1959-02-01  176044.0
# 1959-03-01  176274.0
# 1959-04-01  176503.0
# 1959-05-01  176723.0
# ...              ...
# 2020-07-01  330199.0
# 2020-08-01  330368.0
# 2020-09-01  330535.0
# 2020-10-01  330692.0
# 2020-11-01  330829.0
#
# [743 rows x 1 columns]

# %%
current = datetime.datetime(2021, 1, 17)
dates = []

while current > df.index[0]:
    if current < df.index[-1] + datetime.timedelta(weeks=4):
        dates.append(current)
    current -= datetime.timedelta(days=7)

dates.reverse()
dates
# Out:
# [datetime.datetime(1959, 1, 4, 0, 0),
#  datetime.datetime(1959, 1, 11, 0, 0),
#  datetime.datetime(1959, 1, 18, 0, 0),
#  datetime.datetime(1959, 1, 25, 0, 0),
#  datetime.datetime(1959, 2, 1, 0, 0),
#  datetime.datetime(1959, 2, 8, 0, 0),
#  datetime.datetime(1959, 2, 15, 0, 0),
#  datetime.datetime(1959, 2, 22, 0, 0),
#  datetime.datetime(1959, 3, 1, 0, 0),
#  datetime.datetime(1959, 3, 8, 0, 0),
#  datetime.datetime(1959, 3, 15, 0, 0),
#  datetime.datetime(1959, 3, 22, 0, 0),
#  datetime.datetime(1959, 3, 29, 0, 0),
#  datetime.datetime(1959, 4, 5, 0, 0),
#  datetime.datetime(1959, 4, 12, 0, 0),
#  datetime.datetime(1959, 4, 19, 0, 0),
#  datetime.datetime(1959, 4, 26, 0, 0),
#  datetime.datetime(1959, 5, 3, 0, 0),
#  datetime.datetime(1959, 5, 10, 0, 0),
#  datetime.datetime(1959, 5, 17, 0, 0),
#  datetime.datetime(1959, 5, 24, 0, 0),
#  datetime.datetime(1959, 5, 31, 0, 0),
#  datetime.datetime(1959, 6, 7, 0, 0),
#  datetime.datetime(1959, 6, 14, 0, 0),
# ...

# %%
population = []

i = 0

while i < len(dates):
    cur = dates[i]
    weeks = 0
    
    for j in range(3, 6):
        nxt = cur + datetime.timedelta(weeks=j)
        if nxt.month != cur.month:
            weeks = j
            break

    assert(weeks != 0)
    
    start_time = datetime.datetime(cur.year, cur.month, 1)
    nxt = cur + datetime.timedelta(weeks=weeks)
    end_time = datetime.datetime(nxt.year, nxt.month, 1)
    
    if end_time > df.index[-1]:
        break

    pop_tm = df.loc[start_time, 'POPTHM']
    pop_nm = df.loc[end_time, 'POPTHM']
    incr = (pop_nm - pop_tm) / weeks
    
    for j in range(weeks):
        population.append(pop_tm + j * incr)
    
    i += weeks
    
population
# Out:
# [175818.0,
#  175874.5,
#  175931.0,
#  175987.5,
#  176044.0,
#  176101.5,
#  176159.0,
#  176216.5,
#  176274.0,
#  176319.8,
#  176365.6,
#  176411.4,
#  176457.2,
#  176503.0,
#  176558.0,
#  176613.0,
#  176668.0,
#  176723.0,
#  176769.2,
#  176815.4,
#  176861.6,
#  176907.8,
#  176954.0,
#  177017.5,
#  177081.0,
#  177144.5,
#  177208.0,
#  177275.75,
#  177343.5,
#  177411.25,
#  177479.0,
#  177534.2,
#  177589.4,
#  177644.6,
#  177699.8,
#  177755.0,
#  177822.75,
#  177890.5,
#  177958.25,
#  178026.0,
#  178087.75,
#  178149.5,
#  178211.25,
#  178273.0,
#  178319.2,
#  178365.4,
#  178411.6,
#  178457.8,
#  178504.0,
#  178609.25,
#  178714.5,
#  178819.75,
#  178925.0,
#  179005.2,
#  179085.4,
#  179165.6,
#  179245.8,
#  179326.0,
#  179421.25,
#  179516.5,
#  179611.75,
#  179707.0,
#  179797.0,
#  179887.0,
#  179977.0,
#  180067.0,
#  180152.25,
#  180237.5,
#  180322.75,
#  180408.0,
#  180472.0,
#  180536.0,
#  180600.0,
#  180664.0,
#  180728.0,
#  180803.0,
# ...

# %%
dates_len = len(dates)
dates_len
# Out:
# 3230

# %%
pop_len = len(population)
pop_len
# Out:
# 3226

# %%
diff = dates_len - pop_len
diff
# Out:
# 4

# %%
res = pd.DataFrame({ 'Week': dates[:-diff], 'Population': population })
res
# Out:
#            Week  Population
# 0    1959-01-04   175818.00
# 1    1959-01-11   175874.50
# 2    1959-01-18   175931.00
# 3    1959-01-25   175987.50
# 4    1959-02-01   176044.00
# ...         ...         ...
# 3221 2020-09-27   330652.75
# 3222 2020-10-04   330692.00
# 3223 2020-10-11   330726.25
# 3224 2020-10-18   330760.50
# 3225 2020-10-25   330794.75
#
# [3226 rows x 2 columns]

# %%
df
# Out:
#               POPTHM
# DATE
# 1959-01-01  175818.0
# 1959-02-01  176044.0
# 1959-03-01  176274.0
# 1959-04-01  176503.0
# 1959-05-01  176723.0
# ...              ...
# 2020-07-01  330199.0
# 2020-08-01  330368.0
# 2020-09-01  330535.0
# 2020-10-01  330692.0
# 2020-11-01  330829.0
#
# [743 rows x 1 columns]

# %%
df.to_csv("../cleansed_data/US_population_weekly.csv", index=False)
